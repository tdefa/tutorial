# %% [markdown]
# # Evaluate marker selection method with scRNA-seq

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scanpy as sc
import pandas as pd
import numpy as np
import scanpy as sc


import numpy as np
import pandas as pd
import scanpy as sc
from sklearn import metrics
from tqdm import tqdm

# %% [markdown]
# ## test list accuracy

# %% [markdown]
# **HANDCRAFTED LIST BASELINE**

# %%
#### HANDCRAFTED LIST BASELINE
# activated  RGCC IRF8 SFXN1
# Intermediate STAT1 CCR7 GBP4 BATF3
# RESTING klf2 
# TEMRA CCL5 NKG7

#intermediate remove BATF3 EEF1A1 KLF2 (to much express)

list_gene = ["RGCC", "IRF8", "SFXN1", "STAT1", "CCR7", "GBP4", "BATF3", "KLF2" , "CCL5", "NKG7" ]
cluster_list = ["Activated"] * 3 + ["Intermediate"] * 4 + ['Resting'] * 1 + ['TEMRA'] * 2
df = pd.DataFrame()
df["markerGene"] = gene_list
df["clusterName"] = cluster_list
df
# Out:
#   markerGene   clusterName
# 0       RGCC     Activated
# 1       IRF8     Activated
# 2      SFXN1     Activated
# 3      STAT1  Intermediate
# 4       CCR7  Intermediate
# 5       GBP4  Intermediate
# 6      BATF3  Intermediate
# 7       KLF2       Resting
# 8       CCL5         TEMRA
# 9       NKG7         TEMRA

# %% [markdown]
# **SET parameter** anndata, cell types, list_gene

# %%
#### add parameter

########## set gene list with csv file
#df = pd.read_csv("/home/tom/Bureau/phd/T_cell/gene_naive_cd8_raw_3002/NSForest_markers.csv")
#df = df[np.isin(df.clusterName, ['Activated', 'Intermediate', 'Resting', 'TEMRA'])]
#list_gene_ns_forest = list(df['markerGene'])
#list_gene = list_gene_ns_forest

#you can aslo choose your custom list 
#list_gene =  ['NPM1', 'EEF1A1', 'ACTB', 'RPL10', 'MALAT1', 'B2M', 'RPLP1', 'RPS2',
#       'CCL4', 'RPL41']

## set anndata
anndata_raw = sc.read(
    "/home/tom/Bureau/phd/T_cell/new_test/GSE212270_integrated_naive_cd8_raw.h5ad")
anndata_raw.X = anndata_raw.raw.X.toarray()

##


list_cell_type = np.array(anndata_raw.obs.Cell_Type)
list_cell_type[np.isin(list_cell_type ,
                   [ 'Undefined1', 'Undefined2'])] = "Undefined"
anndata_raw.obs['Cell_Type'] = list_cell_type


anndata_raw = anndata_raw[:, list_gene]

## set column to target: phase, cell type ...
key_target = 'Cell_Type'

# %% [markdown]
# ### to run classifiaction with cosine distance with the previous parameter

# %%
### to run with the previous parameter
y_true = np.array(anndata_raw.obs[key_target])

scrna_unique_clusters = np.unique(anndata_raw.obs[key_target])

scrna_centroids = []

for i in range(len(scrna_unique_clusters)):
    scrna_centroids.append(np.mean(anndata_raw[
                    anndata_raw.obs[key_target] == scrna_unique_clusters[i]].X, axis=0))

y_pred = []
from tqdm import tqdm
for index_cell  in tqdm(range(anndata_raw.shape[0])):
    rna_seq = anndata_raw.X[index_cell]
    norm_expression_vectors = np.array([rna_seq])
    correlation_array = metrics.pairwise.cosine_similarity(norm_expression_vectors,
                                                           np.array(scrna_centroids))[0]
    index_cluster_max = np.argmax(correlation_array)
    pred_rna_seq = scrna_unique_clusters[index_cluster_max]
    y_pred.append(pred_rna_seq)




print(f"Accuracy {metrics.accuracy_score(y_true, y_pred)}")
cm = metrics.confusion_matrix(y_true, y_pred)
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_true, y_pred, labels=scrna_unique_clusters)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=scrna_unique_clusters)
disp.plot()
plt.show()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 7041/7041 [00:09<00:00, 738.61it/s]
# Accuracy 0.7373952563556313

# %% [markdown]
# ### Run classification without the undefined class

# %%
### to run with the previous parameter
anndata_raw = anndata_raw[anndata_raw.obs[key_target] != "Undefined",:]
y_true = np.array(anndata_raw.obs[key_target])

scrna_unique_clusters = np.unique(anndata_raw.obs[key_target])

scrna_centroids = []

for i in range(len(scrna_unique_clusters)):
    scrna_centroids.append(np.mean(anndata_raw[
                    anndata_raw.obs[key_target] == scrna_unique_clusters[i]].X, axis=0))

y_pred = []
from tqdm import tqdm
for index_cell  in tqdm(range(anndata_raw.shape[0])):
    rna_seq = anndata_raw.X[index_cell]
    norm_expression_vectors = np.array([rna_seq])
    correlation_array = metrics.pairwise.cosine_similarity(norm_expression_vectors,
                                                           np.array(scrna_centroids))[0]
    index_cluster_max = np.argmax(correlation_array)
    pred_rna_seq = scrna_unique_clusters[index_cluster_max]
    y_pred.append(pred_rna_seq)




print(f"Accuracy {metrics.accuracy_score(y_true, y_pred)}")
cm = metrics.confusion_matrix(y_true, y_pred)
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_true, y_pred, labels=scrna_unique_clusters)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=scrna_unique_clusters)
disp.plot()
plt.show()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6971/6971 [00:08<00:00, 815.34it/s]
# Accuracy 0.7852531917945775

# %% [markdown]
# ## plot expression profile per celltype

# %%
df
# Out:
#   markerGene   clusterName
# 0       RGCC     Activated
# 1       IRF8     Activated
# 2      SFXN1     Activated
# 3      STAT1  Intermediate
# 4       CCR7  Intermediate
# 5       GBP4  Intermediate
# 6      BATF3  Intermediate
# 7       KLF2       Resting
# 8       CCL5         TEMRA
# 9       NKG7         TEMRA

# %%
anndata_raw = sc.read(
    "/home/tom/Bureau/phd/T_cell/new_test/GSE212270_integrated_naive_cd8_raw.h5ad")
anndata_raw.X = anndata_raw.raw.X.toarray()

# %%
import warnings
warnings.filterwarnings("ignore")
sc.pl.violin(anndata_raw, keys=list_gene, groupby='Cell_Type',
             rotation=90, save='violin_phase.pdf',   use_raw=False)
# Out:
# WARNING: saving figure to file figures/violinviolin_phase.pdf
